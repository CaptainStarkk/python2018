# %%
name = input('궁금한 지역(시/도)를 입력해주세요 : ')

import csv

#공연장
a = open('공연장.csv')
a = open('공연장.csv', 'r', encoding='UTF8')

a = csv.reader(a)
a = list(a)
ay = []
av = []

for az in a :
    if name in az[2] :
        ay.append(az[2])

for ax in ay : 
    aw = ax.split(' ')
    au = aw[2]
    if au[-1] == '구' :
        av.append(aw[2])
    else :
        av.append(aw[1])
        
#게임장
b = open('게임장.csv')
b = open('게임장.csv', 'r', encoding='UTF8')

b = csv.reader(b)
b = list(b)
by = []
bv = []

for bz in b :
    if name in bz[2] :
        by.append(bz[2])

for bx in by : 
    bw = bx.split(' ')
    bu = bw[2]
    if bu[-1] == '구' :
        bv.append(bw[2])
    else :
        bv.append(bw[1])
        
#노래방
c = open('노래방.csv')
c = open('노래방.csv', 'r', encoding='UTF8')

c = csv.reader(c)
c = list(c)
cy = []
cv = []

for cz in c :
    if name in cz[2] :
        cy.append(cz[2])

for cx in cy : 
    cw = cx.split(' ')
    cu = cw[2]
    if cu[-1] == '구' :
        cv.append(cw[2])
    else :
        cv.append(cw[1])

#당구장
d = open('당구장.csv')
d = open('당구장.csv', 'r', encoding='UTF8')

d = csv.reader(d)
d = list(d)
dy = []
dv = []

for dz in d :
    if name in dz[2] :
        dy.append(dz[2])

for dx in dy : 
    dw = dx.split(' ')
    du = dw[2]
    if du[-1] == '구' :
        dv.append(dw[2])
    else :
        dv.append(dw[1])
        
#영화관
e = open('영화관.csv')
e = open('영화관.csv', 'r', encoding='UTF8')

e = csv.reader(e)
e = list(e)
ey = []
ev = []

for ez in e :
    if name in ez[2] :
        ey.append(ez[2])

for ex in ey : 
    ew = ex.split(' ')
    eu = ew[2]
    if eu[-1] == '구' :
        ev.append(ew[2])
    else :
        ev.append(ew[1])
        
#PC방
f = open('PC방.csv')
f = open('PC방.csv', 'r', encoding='UTF8')

f = csv.reader(f)
f = list(f)
fy = []
fv = []

for fz in f :
    if name in fz[2] :
        fy.append(fz[2])

for fx in fy : 
    fw = fx.split(' ')
    fu = fw[2]
    if fu[-1] == '구' :
        fv.append(fw[2])
    else :
        fv.append(fw[1])

        
        
        
        
count = {}
        
for town in av :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in bv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in cv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in dv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in ev :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1
        
for town in fv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

total = []
result = sorted(count.items(),key = lambda t:t[1])
for i in result :
    total.append(result)
print(total)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 : 대구
# [[('달성군', 273), ('중구', 284), ('남구', 306), ('서구', 364), ('수성구', 519), ('해운대구', 550), ('동구', 557), ('북구', 708), ('달서구', 1080)], [('달성군', 273), ('중구', 284), ('남구', 306), ('서구', 364), ('수성구', 519), ('해운대구', 550), ('동구', 557), ('북구', 708), ('달서구', 1080)], [('달성군', 273), ('중구', 284), ('남구', 306), ('서구', 364), ('수성구', 519), ('해운대구', 550), ('동구', 557), ('북구', 708), ('달서구', 1080)], [('달성군', 273), ('중구', 284), ('남구', 306), ('서구', 364), ('수성구', 519), ('해운대구', 550), ('동구', 557), ('북구', 708), ('달서구', 1080)], [('달성군', 273), ('중구', 284), ('남구', 306), ('서구', 364), ('수성구', 519), ('해운대구', 550), ('동구', 557), ('북구', 708), ('달서구', 1080)], [('달성군', 273), ('중구', 284), ('남구', 306), ('서구', 364), ('수성구', 519), ('해운대구', 550), ('동구', 557), ('북구', 708), ('달서구', 1080)], [('달성군', 273), ('중구', 284), ('남구', 306), ('서구', 364), ('수성구', 519), ('해운대구', 550), ('동구', 557), ('북구', 708), ('달서구', 1080)], [('달성군', 273), ('중구', 284), ('남구', 306), ('서구', 364), ('수성구', 519), ('해운대구', 550), ('동구', 557), ('북구', 708), ('달서구', 1080)], [('달성군', 273), ('중구', 284), ('남구', 306), ('서구', 364), ('수성구', 519), ('해운대구', 550), ('동구', 557), ('북구', 708), ('달서구', 1080)]]

# %%
name = input('궁금한 지역(시/도)를 입력해주세요 [ex)서울특별시/인천광역시/대전광역시/광주광역시/대구광역시/울산광역시/부산광역시/경기도/강원도/충청북도/충청남도/전라북도/전라남도/경상북도/경상남도] : ')

import csv

#공연장
a = open('공연장.csv')
a = open('공연장.csv', 'r', encoding='UTF8')

a = csv.reader(a)
a = list(a)
ay = []
av = []

for az in a :
    if name in az[2] :
        ay.append(az[2])

for ax in ay : 
    aw = ax.split(' ')
    au = aw[2]
    if au[-1] == '구' :
        av.append(aw[2])
    else :
        av.append(aw[1])
        
#게임장
b = open('게임장.csv')
b = open('게임장.csv', 'r', encoding='UTF8')

b = csv.reader(b)
b = list(b)
by = []
bv = []

for bz in b :
    if name in bz[2] :
        by.append(bz[2])

for bx in by : 
    bw = bx.split(' ')
    bu = bw[2]
    if bu[-1] == '구' :
        bv.append(bw[2])
    else :
        bv.append(bw[1])
        
#노래방
c = open('노래방.csv')
c = open('노래방.csv', 'r', encoding='UTF8')

c = csv.reader(c)
c = list(c)
cy = []
cv = []

for cz in c :
    if name in cz[2] :
        cy.append(cz[2])

for cx in cy : 
    cw = cx.split(' ')
    cu = cw[2]
    if cu[-1] == '구' :
        cv.append(cw[2])
    else :
        cv.append(cw[1])

#당구장
d = open('당구장.csv')
d = open('당구장.csv', 'r', encoding='UTF8')

d = csv.reader(d)
d = list(d)
dy = []
dv = []

for dz in d :
    if name in dz[2] :
        dy.append(dz[2])

for dx in dy : 
    dw = dx.split(' ')
    du = dw[2]
    if du[-1] == '구' :
        dv.append(dw[2])
    else :
        dv.append(dw[1])
        
#영화관
e = open('영화관.csv')
e = open('영화관.csv', 'r', encoding='UTF8')

e = csv.reader(e)
e = list(e)
ey = []
ev = []

for ez in e :
    if name in ez[2] :
        ey.append(ez[2])

for ex in ey : 
    ew = ex.split(' ')
    eu = ew[2]
    if eu[-1] == '구' :
        ev.append(ew[2])
    else :
        ev.append(ew[1])
        
#PC방
f = open('PC방.csv')
f = open('PC방.csv', 'r', encoding='UTF8')

f = csv.reader(f)
f = list(f)
fy = []
fv = []

for fz in f :
    if name in fz[2] :
        fy.append(fz[2])

for fx in fy : 
    fw = fx.split(' ')
    fu = fw[2]
    if fu[-1] == '구' :
        fv.append(fw[2])
    else :
        fv.append(fw[1])

        
        
        
        
count = {}
        
for town in av :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in bv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in cv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in dv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in ev :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1
        
for town in fv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

result = sorted(count.items(), key = lambda t : t[1], reverse=True)
print(result)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 [ex)서울특별시/인천광역시/대전광역시/광주광역시/대구광역시/울산광역시/부산광역시/경기도/강원도/충청북도/충청남도/전라북도/전라남도/경상북도/경상남도] : 부산
# [('해운대구', 550), ('사상구', 470), ('부산진구', 464), ('동래구', 453), ('금정구', 421), ('사하구', 405), ('북구', 383), ('남구', 319), ('연제구', 261), ('수영구', 246), ('기장군', 197), ('중구', 176), ('영도구', 144), ('서구', 109), ('동구', 96), ('강서구', 67), ('의창구', 1)]

# %%
name = input('궁금한 지역(시/도)를 입력해주세요 : ')

import csv

#공연장
a = open('공연장.csv')
a = open('공연장.csv', 'r', encoding='UTF8')

a = csv.reader(a)
a = list(a)
ay = []
av = []

for az in a :
    if name in az[2] :
        ay.append(az[2])

for ax in ay : 
    aw = ax.split(' ')
    au = aw[2]
    if au[-1] == '구' :
        av.append(aw[3])
    else :
        av.append(aw[2])
        
#게임장
b = open('게임장.csv')
b = open('게임장.csv', 'r', encoding='UTF8')

b = csv.reader(b)
b = list(b)
by = []
bv = []

for bz in b :
    if name in bz[2] :
        by.append(bz[2])

for bx in by : 
    bw = bx.split(' ')
    bu = bw[2]
    if bu[-1] == '구' :
        bv.append(bw[3])
    else :
        bv.append(bw[2])
        
#노래방
c = open('노래방.csv')
c = open('노래방.csv', 'r', encoding='UTF8')

c = csv.reader(c)
c = list(c)
cy = []
cv = []

for cz in c :
    if name in cz[2] :
        cy.append(cz[2])

for cx in cy : 
    cw = cx.split(' ')
    cu = cw[2]
    if cu[-1] == '구' :
        cv.append(cw[3])
    else :
        cv.append(cw[2])

#당구장
d = open('당구장.csv')
d = open('당구장.csv', 'r', encoding='UTF8')

d = csv.reader(d)
d = list(d)
dy = []
dv = []

for dz in d :
    if name in dz[2] :
        dy.append(dz[2])

for dx in dy : 
    dw = dx.split(' ')
    du = dw[2]
    if du[-1] == '구' :
        dv.append(dw[3])
    else :
        dv.append(dw[2])
        
#영화관
e = open('영화관.csv')
e = open('영화관.csv', 'r', encoding='UTF8')

e = csv.reader(e)
e = list(e)
ey = []
ev = []

for ez in e :
    if name in ez[2] :
        ey.append(ez[2])

for ex in ey : 
    ew = ex.split(' ')
    eu = ew[2]
    if eu[-1] == '구' :
        ev.append(ew[3])
    else :
        ev.append(ew[2])
        
#PC방
f = open('PC방.csv')
f = open('PC방.csv', 'r', encoding='UTF8')

f = csv.reader(f)
f = list(f)
fy = []
fv = []

for fz in f :
    if name in fz[2] :
        fy.append(fz[2])

for fx in fy : 
    fw = fx.split(' ')
    fu = fw[2]
    if fu[-1] == '구' :
        fv.append(fw[3])
    else :
        fv.append(fw[2])

        
        
        
        
count = {}
        
for town in av :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in bv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in cv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in dv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in ev :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1
        
for town in fv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

total = []
result = sorted(count.items(),key = lambda t:t[1])
for i in result :
    total.append(result)
print(total)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 : 서울
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
