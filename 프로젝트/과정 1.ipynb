# %%
name = input('궁금한 지역(시/도)를 입력해주세요 : ')

import csv


data = csv.reader(a)
data = list(data)
공연장 = []

for row in data :
    if name in row[2] :
        for 공연장 in data : 
            공연장.append(data)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 : tjdnf
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-12-dd9912674eb2> in <module>()
#       5
#       6 data = csv.reader(a)
# ----> 7 data = list(data)
#       8 공연장 = []
#       9
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0x80 in position 25: illegal multibyte sequence

# %%
name = input('궁금한 지역(시/도)를 입력해주세요 : ')

import csv

a = open('공연장.csv')
a = open('공연장.csv', 'r', encoding='UTF8')

a = csv.reader(a)
a = list(a)
con = []

for row in a :
    if name in row[2] :
        con.append(row[2])

print(con)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 : 서울
# ...

# %%
name = input('궁금한 지역(시/도)를 입력해주세요 : ')

import csv

a = open('공연장.csv')
a = open('공연장.csv', 'r', encoding='UTF8')

a = csv.reader(a)
a = list(a)
con = []

for row in a :
    con.append(row[2])
print(con)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 : 서울
# ...

# %%
name = input('궁금한 지역(시/도)를 입력해주세요 : ')

import csv

a = open('공연장.csv')
a = open('공연장.csv', 'r', encoding='UTF8')

a = csv.reader(a)
a = list(a)
con = []

for ax in a :
    if name in ax[2] :
        con.append(ax[2])

print(con)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 : 서울
# ...

# %%
name = input('궁금한 지역(시/도)를 입력해주세요 : ')

import csv

a = open('공연장.csv')
a = open('공연장.csv', 'r', encoding='UTF8')

a = csv.reader(a)
a = list(a)
ay = []
av = []

for az in a :
    if name in az[2] :
        ay.append(az[2])

for ax in ay : 
    aw = ax.split(' ')
    av.append(aw[2])

print(av)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 : 경상남도
# ['어방동', '일운면', '동림동', '대방동', '대방동', '교동', '교동', '남해읍', '도남동', '도남동', '도남동', '용남면', '도남동', '도남동', '창녕읍', '창녕읍', '금서면', '금서면', '칠암동', '판문동', '동성동', '의령읍', '함양읍', '함양읍', '외동', '의창구', '평거동', '가야읍', '가야읍', '고성읍', '거창읍', '거창읍', '삼방동', '대청동', '외동', '내동', '내동', '내동', '진영읍', '봉황동', '의창구', '내동면', '충무공동', '실안동', '옥포동', '장승포동', '고현동', '장승포동', '합천읍', '용주면', '동림동', '의창구', '의창구', '진해구', '마산회원구', '마산회원구', '진해구', '의창구', '남부동', '남부동', '하동읍']

# %%
name = input('궁금한 지역(시/도)를 입력해주세요 : ')

import csv

a = open('공연장.csv')
a = open('공연장.csv', 'r', encoding='UTF8')

a = csv.reader(a)
a = list(a)
ay = []
av = []

for az in a :
    if name in az[2] :
        ay.append(az[2])

for ax in ay : 
    aw = ax.split(' ')
    au = aw[2]
    if au[-1] == '구' :
        av.append(aw[3])
    else :
        av.append(aw[2])

print(av)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 : 경상남도
# ['어방동', '일운면', '동림동', '대방동', '대방동', '교동', '교동', '남해읍', '도남동', '도남동', '도남동', '용남면', '도남동', '도남동', '창녕읍', '창녕읍', '금서면', '금서면', '칠암동', '판문동', '동성동', '의령읍', '함양읍', '함양읍', '외동', '용호동', '평거동', '가야읍', '가야읍', '고성읍', '거창읍', '거창읍', '삼방동', '대청동', '외동', '내동', '내동', '내동', '진영읍', '봉황동', '팔용동', '내동면', '충무공동', '실안동', '옥포동', '장승포동', '고현동', '장승포동', '합천읍', '용주면', '동림동', '용호동', '용호동', '태백동', '양덕동', '양덕동', '덕산동', '명서동', '남부동', '남부동', '하동읍']

# %%
name = input('궁금한 지역(시/도)를 입력해주세요 : ')

import csv

a = open('공연장.csv')
a = open('공연장.csv', 'r', encoding='UTF8')

a = csv.reader(a)
a = list(a)
ay = []
av = []

for az in a :
    if name in az[2] :
        ay.append(az[2])

for ax in ay : 
    aw = ax.split(' ')
    au = aw[2]
    if au[-1] == '구' :
        av.append(aw[3])
    else :
        av.append(aw[2])



count = {}
        
for town in av :
    if town in count:
        count[town] +=1
    else:
        count[town] = 1        

print(count)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 : 부산
# {'범일동': 5, '일광면': 1, '덕천동': 1, '구포동': 2, '대연동': 16, '연지동': 2, '부전동': 1, '부암동': 1, '범천동': 1, '하단동': 2, '남천동': 4, '장전동': 3, '동삼동': 3, '광안동': 2, '우동': 6, '좌동': 2, '중동': 2, '구서동': 2, '두구동': 1, '거제동': 1, '온천동': 2, '금사동': 1, '망미동': 1, '대청동4가': 1, '영주동': 2, '남포동2가': 2, '장안읍': 1, '괘법동': 1, '학장동': 1, '수영동': 1, '남포동5가': 1, '명륜동': 2}

# %%
name = input('궁금한 지역(시/도)를 입력해주세요 : ')

import csv

#공연장
a = open('공연장.csv')
a = open('공연장.csv', 'r', encoding='UTF8')

a = csv.reader(a)
a = list(a)
ay = []
av = []

for az in a :
    if name in az[2] :
        ay.append(az[2])

for ax in ay : 
    aw = ax.split(' ')
    au = aw[2]
    if au[-1] == '구' :
        av.append(aw[3])
    else :
        av.append(aw[2])
        
#게임장
b = open('게임장.csv')
b = open('게임장.csv', 'r', encoding='UTF8')

b = csv.reader(b)
b = list(b)
by = []
bv = []

for bz in b :
    if name in bz[2] :
        by.append(bz[2])

for bx in by : 
    bw = bx.split(' ')
    bu = bw[2]
    if bu[-1] == '구' :
        bv.append(bw[3])
    else :
        bv.append(bw[2])
        
#노래방
c = open('노래방.csv')
c = open('노래방.csv', 'r', encoding='UTF8')

c = csv.reader(c)
c = list(c)
cy = []
cv = []

for cz in c :
    if name in cz[2] :
        cy.append(cz[2])

for cx in cy : 
    cw = cx.split(' ')
    cu = cw[2]
    if cu[-1] == '구' :
        cv.append(cw[3])
    else :
        cv.append(cw[2])

#당구장
d = open('당구장.csv')
d = open('당구장.csv', 'r', encoding='UTF8')

d = csv.reader(d)
d = list(d)
dy = []
dv = []

for dz in d :
    if name in dz[2] :
        dy.append(dz[2])

for dx in dy : 
    dw = dx.split(' ')
    du = dw[2]
    if du[-1] == '구' :
        dv.append(dw[3])
    else :
        dv.append(dw[2])
        
#영화관
e = open('영화관.csv')
e = open('영화관.csv', 'r', encoding='UTF8')

e = csv.reader(e)
e = list(e)
ey = []
ev = []

for ez in e :
    if name in ez[2] :
        ey.append(ez[2])

for ex in ey : 
    ew = ex.split(' ')
    eu = ew[2]
    if eu[-1] == '구' :
        ev.append(ew[3])
    else :
        ev.append(ew[2])
        
#PC방
f = open('PC방.csv')
f = open('PC방.csv', 'r', encoding='UTF8')

f = csv.reader(f)
f = list(f)
fy = []
fv = []

for fz in f :
    if name in fz[2] :
        fy.append(fz[2])

for fx in fy : 
    fw = fx.split(' ')
    fu = fw[2]
    if fu[-1] == '구' :
        fv.append(fw[3])
    else :
        fv.append(fw[2])

        
        
        
        
count = {}
        
for town in av :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in bv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in cv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in dv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in ev :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1
        
for town in fv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1
        
print(count)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 : 대구
# ...

# %%
name = input('궁금한 지역(시/도)를 입력해주세요 : ')

import csv

#공연장
a = open('공연장.csv')
a = open('공연장.csv', 'r', encoding='UTF8')

a = csv.reader(a)
a = list(a)
ay = []
av = []

for az in a :
    if name in az[2] :
        ay.append(az[2])

for ax in ay : 
    aw = ax.split(' ')
    au = aw[2]
    if au[-1] == '구' :
        av.append(aw[3])
    else :
        av.append(aw[2])
        
#게임장
b = open('게임장.csv')
b = open('게임장.csv', 'r', encoding='UTF8')

b = csv.reader(b)
b = list(b)
by = []
bv = []

for bz in b :
    if name in bz[2] :
        by.append(bz[2])

for bx in by : 
    bw = bx.split(' ')
    bu = bw[2]
    if bu[-1] == '구' :
        bv.append(bw[3])
    else :
        bv.append(bw[2])
        
#노래방
c = open('노래방.csv')
c = open('노래방.csv', 'r', encoding='UTF8')

c = csv.reader(c)
c = list(c)
cy = []
cv = []

for cz in c :
    if name in cz[2] :
        cy.append(cz[2])

for cx in cy : 
    cw = cx.split(' ')
    cu = cw[2]
    if cu[-1] == '구' :
        cv.append(cw[3])
    else :
        cv.append(cw[2])

#당구장
d = open('당구장.csv')
d = open('당구장.csv', 'r', encoding='UTF8')

d = csv.reader(d)
d = list(d)
dy = []
dv = []

for dz in d :
    if name in dz[2] :
        dy.append(dz[2])

for dx in dy : 
    dw = dx.split(' ')
    du = dw[2]
    if du[-1] == '구' :
        dv.append(dw[3])
    else :
        dv.append(dw[2])
        
#영화관
e = open('영화관.csv')
e = open('영화관.csv', 'r', encoding='UTF8')

e = csv.reader(e)
e = list(e)
ey = []
ev = []

for ez in e :
    if name in ez[2] :
        ey.append(ez[2])

for ex in ey : 
    ew = ex.split(' ')
    eu = ew[2]
    if eu[-1] == '구' :
        ev.append(ew[3])
    else :
        ev.append(ew[2])
        
#PC방
f = open('PC방.csv')
f = open('PC방.csv', 'r', encoding='UTF8')

f = csv.reader(f)
f = list(f)
fy = []
fv = []

for fz in f :
    if name in fz[2] :
        fy.append(fz[2])

for fx in fy : 
    fw = fx.split(' ')
    fu = fw[2]
    if fu[-1] == '구' :
        fv.append(fw[3])
    else :
        fv.append(fw[2])

        
        
        
        
count = {}
        
for town in av :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in bv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in cv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in dv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in ev :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1
        
for town in fv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

total = []
result = sorted(count.items(),key = lambda t:t[1])
total.append(result)
print(total)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 : 서울
# ...

# %% [raw]
# name = input('궁금한 지역(시/도)를 입력해주세요 : ')
#
# import csv
#
# #공연장
# a = open('공연장.csv')
# a = open('공연장.csv', 'r', encoding='UTF8')
#
# a = csv.reader(a)
# a = list(a)
# ay = []
# av = []
#
# for az in a :
#     if name in az[2] :
#         ay.append(az[2])
#
# for ax in ay :
#     aw = ax.split(' ')
#     au = aw[2]
#     if au[-1] == '구' :
#         av.append(aw[2])
#     else :
#         av.append(aw[1])
#
# #게임장
# b = open('게임장.csv')
# b = open('게임장.csv', 'r', encoding='UTF8')
#
# b = csv.reader(b)
# b = list(b)
# by = []
# bv = []
#
# for bz in b :
#     if name in bz[2] :
#         by.append(bz[2])
#
# for bx in by :
#     bw = bx.split(' ')
#     bu = bw[2]
#     if bu[-1] == '구' :
#         bv.append(bw[2])
#     else :
#         bv.append(bw[1])
#
# #노래방
# c = open('노래방.csv')
# c = open('노래방.csv', 'r', encoding='UTF8')
#
# c = csv.reader(c)
# c = list(c)
# cy = []
# cv = []
#
# for cz in c :
#     if name in cz[2] :
#         cy.append(cz[2])
#
# for cx in cy :
#     cw = cx.split(' ')
#     cu = cw[2]
#     if cu[-1] == '구' :
#         cv.append(cw[2])
#     else :
#         cv.append(cw[1])
#
# #당구장
# d = open('당구장.csv')
# d = open('당구장.csv', 'r', encoding='UTF8')
#
# d = csv.reader(d)
# d = list(d)
# dy = []
# dv = []
#
# for dz in d :
#     if name in dz[2] :
#         dy.append(dz[2])
#
# for dx in dy :
#     dw = dx.split(' ')
#     du = dw[2]
#     if du[-1] == '구' :
#         dv.append(dw[2])
#     else :
#         dv.append(dw[1])
#
# #영화관
# e = open('영화관.csv')
# e = open('영화관.csv', 'r', encoding='UTF8')
#
# e = csv.reader(e)
# e = list(e)
# ey = []
# ev = []
#
# for ez in e :
#     if name in ez[2] :
#         ey.append(ez[2])
#
# for ex in ey :
#     ew = ex.split(' ')
#     eu = ew[2]
#     if eu[-1] == '구' :
#         ev.append(ew[2])
#     else :
#         ev.append(ew[1])
#
# #PC방
# f = open('PC방.csv')
# f = open('PC방.csv', 'r', encoding='UTF8')
#
# f = csv.reader(f)
# f = list(f)
# fy = []
# fv = []
#
# for fz in f :
#     if name in fz[2] :
#         fy.append(fz[2])
#
# for fx in fy :
#     fw = fx.split(' ')
#     fu = fw[2]
#     if fu[-1] == '구' :
#         fv.append(fw[2])
#     else :
#         fv.append(fw[1])
#
#
#
#
#
# count = {}
#
# for town in av :
#     if town in count :
#         count[town] +=1
#     else :
#         count[town] = 1
#
# for town in bv :
#     if town in count :
#         count[town] +=1
#     else :
#         count[town] = 1
#
# for town in cv :
#     if town in count :
#         count[town] +=1
#     else :
#         count[town] = 1
#
# for town in dv :
#     if town in count :
#         count[town] +=1
#     else :
#         count[town] = 1
#
# for town in ev :
#     if town in count :
#         count[town] +=1
#     else :
#         count[town] = 1
#
# for town in fv :
#     if town in count :
#         count[town] +=1
#     else :
#         count[town] = 1
#
# total = []
# result = sorted(count.items(),key = lambda t:t[1])
# for i in result :
#     total.append(result)
# print(total)
