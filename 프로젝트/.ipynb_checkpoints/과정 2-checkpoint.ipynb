# %%
name = input('궁금한 지역(시/도)를 입력해주세요 : ')

import csv

#공연장
a = open('공연장.csv')
a = open('공연장.csv', 'r', encoding='UTF8')

a = csv.reader(a)
a = list(a)
ay = []
av = []

for az in a :
    if name in az[2] :
        ay.append(az[2])

for ax in ay : 
    aw = ax.split(' ')
    au = aw[2]
    if au[-1] == '구' :
        av.append(aw[2])
    else :
        av.append(aw[1])
        
#게임장
b = open('게임장.csv')
b = open('게임장.csv', 'r', encoding='UTF8')

b = csv.reader(b)
b = list(b)
by = []
bv = []

for bz in b :
    if name in bz[2] :
        by.append(bz[2])

for bx in by : 
    bw = bx.split(' ')
    bu = bw[2]
    if bu[-1] == '구' :
        bv.append(bw[2])
    else :
        bv.append(bw[1])
        
#노래방
c = open('노래방.csv')
c = open('노래방.csv', 'r', encoding='UTF8')

c = csv.reader(c)
c = list(c)
cy = []
cv = []

for cz in c :
    if name in cz[2] :
        cy.append(cz[2])

for cx in cy : 
    cw = cx.split(' ')
    cu = cw[2]
    if cu[-1] == '구' :
        cv.append(cw[2])
    else :
        cv.append(cw[1])

#당구장
d = open('당구장.csv')
d = open('당구장.csv', 'r', encoding='UTF8')

d = csv.reader(d)
d = list(d)
dy = []
dv = []

for dz in d :
    if name in dz[2] :
        dy.append(dz[2])

for dx in dy : 
    dw = dx.split(' ')
    du = dw[2]
    if du[-1] == '구' :
        dv.append(dw[2])
    else :
        dv.append(dw[1])
        
#영화관
e = open('영화관.csv')
e = open('영화관.csv', 'r', encoding='UTF8')

e = csv.reader(e)
e = list(e)
ey = []
ev = []

for ez in e :
    if name in ez[2] :
        ey.append(ez[2])

for ex in ey : 
    ew = ex.split(' ')
    eu = ew[2]
    if eu[-1] == '구' :
        ev.append(ew[2])
    else :
        ev.append(ew[1])
        
#PC방
f = open('PC방.csv')
f = open('PC방.csv', 'r', encoding='UTF8')

f = csv.reader(f)
f = list(f)
fy = []
fv = []

for fz in f :
    if name in fz[2] :
        fy.append(fz[2])

for fx in fy : 
    fw = fx.split(' ')
    fu = fw[2]
    if fu[-1] == '구' :
        fv.append(fw[2])
    else :
        fv.append(fw[1])

        
        
        
        
count = {}
        
for town in av :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in bv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in cv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in dv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in ev :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1
        
for town in fv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

result = sorted(count.items(), key = lambda t : t[1], reverse=True)
result = list(result)
resultt = [list(result[0])[0],list(result[1])[0],list(result[2])[0]]
print(result)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 : 제주특별자치도
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-97159be90747> in <module>()
#     173 result = sorted(count.items(), key = lambda t : t[1], reverse=True)
#     174 result = list(result)
# --> 175 resultt = [list(result[0])[0],list(result[1])[0],list(result[2])[0]]
#     176 print(result)
#
# IndexError: list index out of range

# %%
name = input('궁금한 지역(시/도)를 입력해주세요 [ex)서울특별시/인천광역시/대전광역시/광주광역시/대구광역시/울산광역시/부산광역시/경기도/강원도/충청북도/충청남도/전라북도/전라남도/경상북도/경상남도] : ')

import csv

#공연장
a = open('공연장.csv')
a = open('공연장.csv', 'r', encoding='UTF8')

a = csv.reader(a)
a = list(a)
ay = []
av = []

for az in a :
    if name in az[2] :
        ay.append(az[2])

for ax in ay : 
    aw = ax.split(' ')
    au = aw[2]
    if au[-1] == '구' :
        av.append(aw[2])
    else :
        av.append(aw[1])
        
#게임장
b = open('게임장.csv')
b = open('게임장.csv', 'r', encoding='UTF8')

b = csv.reader(b)
b = list(b)
by = []
bv = []

for bz in b :
    if name in bz[2] :
        by.append(bz[2])

for bx in by : 
    bw = bx.split(' ')
    bu = bw[2]
    if bu[-1] == '구' :
        bv.append(bw[2])
    else :
        bv.append(bw[1])
        
#노래방
c = open('노래방.csv')
c = open('노래방.csv', 'r', encoding='UTF8')

c = csv.reader(c)
c = list(c)
cy = []
cv = []

for cz in c :
    if name in cz[2] :
        cy.append(cz[2])

for cx in cy : 
    cw = cx.split(' ')
    cu = cw[2]
    if cu[-1] == '구' :
        cv.append(cw[2])
    else :
        cv.append(cw[1])

#당구장
d = open('당구장.csv')
d = open('당구장.csv', 'r', encoding='UTF8')

d = csv.reader(d)
d = list(d)
dy = []
dv = []

for dz in d :
    if name in dz[2] :
        dy.append(dz[2])

for dx in dy : 
    dw = dx.split(' ')
    du = dw[2]
    if du[-1] == '구' :
        dv.append(dw[2])
    else :
        dv.append(dw[1])
        
#영화관
e = open('영화관.csv')
e = open('영화관.csv', 'r', encoding='UTF8')

e = csv.reader(e)
e = list(e)
ey = []
ev = []

for ez in e :
    if name in ez[2] :
        ey.append(ez[2])

for ex in ey : 
    ew = ex.split(' ')
    eu = ew[2]
    if eu[-1] == '구' :
        ev.append(ew[2])
    else :
        ev.append(ew[1])
        
#PC방
f = open('PC방.csv')
f = open('PC방.csv', 'r', encoding='UTF8')

f = csv.reader(f)
f = list(f)
fy = []
fv = []

for fz in f :
    if name in fz[2] :
        fy.append(fz[2])

for fx in fy : 
    fw = fx.split(' ')
    fu = fw[2]
    if fu[-1] == '구' :
        fv.append(fw[2])
    else :
        fv.append(fw[1])
        
count = {}
        
for town in av :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in bv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in cv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in dv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

for town in ev :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1
        
for town in fv :
    if town in count :
        count[town] +=1
    else :
        count[town] = 1

result = sorted(count.items(), key = lambda t : t[1], reverse=True)
result = list(result)
resultt = [list(result[0])[0],list(result[1])[0],list(result[2])[0]]
print(name,'의 핫플(시/군/구) TOP3 :',resultt)

#공연장
at = []
ar = []

for az in a :
    if resultt[0] in az[2] or resultt[1] in az[2] or resultt[2] in az[2] :
        at.append(az[2])

for ax in at : 
    aw = ax.split(' ')
    au = aw[2]
    if au[-1] == '구' :
        ar.append(aw[3])
    else :
        ar.append(aw[2])
        
#게임장
bt = []
br = []

for bz in b :
    if resultt[0] in bz[2] or resultt[1] in bz[2] or resultt[2] in bz[2] :
        bt.append(bz[2])

for bx in bt : 
    bw = bx.split(' ')
    bu = bw[2]
    if bu[-1] == '구' :
        br.append(bw[3])
    else :
        br.append(bw[2])
        
#노래방
ct = []
cr = []

for cz in c :
    if resultt[0] in cz[2] or resultt[1] in cz[2] or resultt[2] in cz[2] :
        ct.append(cz[2])

for cx in ct : 
    cw = cx.split(' ')
    cu = cw[2]
    if cu[-1] == '구' :
        cr.append(cw[3])
    else :
        cr.append(cw[2])
        
#당구장
dt = []
dr = []

for dz in d :
    if resultt[0] in dz[2] or resultt[1] in dz[2] or resultt[2] in dz[2] :
        dt.append(dz[2])

for dx in dt : 
    dw = dx.split(' ')
    du = dw[2]
    if du[-1] == '구' :
        dr.append(dw[3])
    else :
        dr.append(dw[2])
        
#영화관
et = []
er = []

for ez in e :
    if resultt[0] in ez[2] or resultt[1] in ez[2] or resultt[2] in ez[2] :
        et.append(ez[2])

for ex in et : 
    ew = ex.split(' ')
    eu = ew[2]
    if eu[-1] == '구' :
        er.append(ew[3])
    else :
        er.append(ew[2])
        
#PC방
ft = []
fr = []

for fz in f :
    if resultt[0] in fz[2] or resultt[1] in fz[2] or resultt[2] in fz[2] :
        ft.append(fz[2])

for fx in ft : 
    fw = fx.split(' ')
    fu = fw[2]
    if fu[-1] == '구' :
        fr.append(fw[3])
    else :
        fr.append(fw[2])
        
countt = {}
        
for town in ar :
    if town in countt :
        countt[town] +=1
    else :
        countt[town] = 1

for town in br :
    if town in countt :
        countt[town] +=1
    else :
        countt[town] = 1

for town in cr :
    if town in countt :
        countt[town] +=1
    else :
        countt[town] = 1

for town in dr :
    if town in countt :
        countt[town] +=1
    else :
        countt[town] = 1

for town in er :
    if town in countt :
        countt[town] +=1
    else :
        countt[town] = 1
        
for town in fr :
    if town in countt :
        countt[town] +=1
    else :
        countt[town] = 1

total = sorted(countt.items(), key = lambda t : t[1], reverse=True)
print(name,'의 핫플(읍/면/동) 순위 :',total)
# Out:
# 궁금한 지역(시/도)를 입력해주세요 [ex)서울특별시/인천광역시/대전광역시/광주광역시/대구광역시/울산광역시/부산광역시/경기도/강원도/충청북도/충청남도/전라북도/전라남도/경상북도/경상남도] : 대구
# 대구 의 핫플(시/군/구) TOP3 : ['달서구', '북구', '동구']
# 대구 의 핫플(읍/면/동) 순위 : [('수유동', 422), ('구월동', 410), ('미아동', 309), ('용봉동', 239), ('장항동', 232), ('만수동', 230), ('성내동', 229), ('논현동', 202), ('간석동', 191), ('두정동', 184), ('천호동', 178), ('성정동', 165), ('행당동', 162), ('백석동', 161), ('쌍용동', 152), ('성수동2가', 147), ('상인동', 146), ('송현동', 138), ('번동', 135), ('이곡동', 123), ('길동', 123), ('구포동', 122), ('두암동', 122), ('운암동', 120), ('산격동', 113), ('태전동', 113), ('오치동', 98), ('신당동', 96), ('두류동', 95), ('화명동', 94), ('신암동', 93), ('용전동', 89), ('암사동', 88), ('신천동', 86), ('효목동', 86), ('죽도동', 85), ('덕천동', 83), ('용산동', 82), ('명일동', 82), ('성수동1가', 73), ('정릉동', 72), ('가양동', 72), ('동천동', 71), ('본리동', 71), ('중산동', 71), ('양산동', 67), ('호계동', 66), ('용답동', 64), ('동선동1가', 62), ('문흥동', 61), ('신안동', 60), ('장위동', 59), ('감삼동', 58), ('방어동', 58), ('호산동', 58), ('우산동', 58), ('안암동5가', 58), ('일곡동', 58), ('중흥동', 57), ('복현동', 57), ('불당동', 56), ('하월곡동', 55), ('율하동', 55), ('두호동', 54), ('성환읍', 52), ('자양동', 52), ('용운동', 52), ('만덕동', 52), ('구암동', 52), ('가오동', 51), ('전하동', 48), ('화정동', 48), ('석관동', 47), ('방촌동', 47), ('양덕동', 46), ('장성동', 44), ('마두동', 42), ('일산동', 42), ('대흥동', 41), ('서부동', 40), ('금호동4가', 40), ('성당동', 39), ('홍도동', 39), ('종암동', 38), ('황금동', 37), ('초량동', 37), ('학동', 37), ('서창동', 35), ('도원동', 35), ('정발산동', 35), ('대현동', 35), ('진천동', 34), ('신용동', 34), ('금곡동', 34), ('둔촌동', 34), ('관음동', 31), ('죽전동', 31), ('흥해읍', 31), ('계림동', 30), ('불로동', 30), ('매곡동', 30), ('남촌동', 30), ('도선동', 30), ('범일동', 29), ('성거읍', 29), ('본동', 29), ('마장동', 29), ('하왕십리동', 29), ('침산동', 28), ('길음동', 28), ('지산동', 28), ('직산읍', 28), ('동부동', 28), ('산수동', 27), ('풍동', 27), ('수정동', 27), ('성남동', 27), ('진장동', 26), ('지저동', 26), ('우이동', 26), ('동호동', 26), ('양정동', 25), ('연암동', 25), ('송정동', 25), ('식사동', 25), ('송림동', 24), ('서변동', 23), ('옥수동', 23), ('칠성동2가', 22), ('상일동', 22), ('신서동', 22), ('봉무동', 22), ('금호동1가', 22), ('읍내동', 22), ('장기동', 21), ('홍익동', 21), ('고덕동', 21), ('입장면', 20), ('명촌동', 20), ('동변동', 20), ('유동', 19), ('신기동', 19), ('신흥동', 19), ('대동', 19), ('대곡동', 18), ('노원동1가', 18), ('삼성동', 18), ('매천동', 17), ('용두동', 17), ('동림동', 17), ('대인동', 16), ('노원동2가', 16), ('금호동2가', 16), ('화봉동', 15), ('월성동', 15), ('고성동3가', 15), ('판암동', 15), ('염포동', 15), ('용흥동', 15), ('충장로1가', 14), ('각산동', 14), ('중동', 14), ('금호동3가', 14), ('상원동', 13), ('덕산동', 13), ('노원동3가', 13), ('각화동', 13), ('동명동', 12), ('학정동', 12), ('입석동', 12), ('대신동', 12), ('광산동', 11), ('천곡동', 11), ('검사동', 10), ('차암동', 10), ('강일동', 10), ('삼선동2가', 10), ('정자동', 10), ('학잠동', 10), ('창포동', 10), ('환호동', 9), ('항구동', 9), ('정동', 9), ('임동', 9), ('파호동', 9), ('낭월동', 9), ('호남동', 8), ('사근동', 8), ('장수동', 8), ('사수동', 8), ('금동', 8), ('화수동', 8), ('호림동', 8), ('서석동', 8), ('효동', 8), ('용계동', 8), ('삼선동1가', 7), ('충장로4가', 7), ('상월곡동', 7), ('산하동', 7), ('대천동', 7), ('국우동', 7), ('도림동', 7), ('기계면', 7), ('우현동', 7), ('지묘동', 7), ('삼각동', 7), ('동소문동2가', 6), ('풍향동', 6), ('동선동2가', 6), ('상왕십리동', 6), ('상안동', 6), ('동소문동3가', 6), ('동소문동5가', 6), ('화평동', 6), ('유천동', 6), ('인동', 6), ('청하면', 6), ('용수동', 6), ('충장로5가', 6), ('돈암동', 5), ('여천동', 5), ('삼선동4가', 5), ('고성동2가', 5), ('금남로5가', 5), ('연제동', 5), ('성북동', 4), ('소태동', 4), ('동선동4가', 4), ('충장로3가', 4), ('응봉동', 4), ('동선동5가', 4), ('보문동4가', 4), ('동빈2가', 4), ('득량동', 4), ('원동', 3), ('생용동', 3), ('충장로2가', 3), ('소제동', 3), ('남빈동', 3), ('좌천동', 3), ('삼선동5가', 3), ('보문동7가', 3), ('만석동', 3), ('검단동', 3), ('칠성동1가', 3), ('운림동', 3), ('대성동', 3), ('문봉동', 3), ('성성동', 3), ('중대동', 3), ('고잔동', 3), ('성북동1가', 2), ('궁동', 2), ('금남로1가', 2), ('송라면', 2), ('대의동', 2), ('누문동', 2), ('보문동5가', 2), ('보문동2가', 2), ('장동', 2), ('중앙동', 2), ('학산동', 2), ('성석동', 2), ('북동', 2), ('달천동', 2), ('신촌동', 1), ('금남로3가', 1), ('목동', 1), ('사복동', 1), ('수기동', 1), ('동소문동6가', 1), ('창영동', 1), ('조야동', 1), ('노곡동', 1), ('팔달동', 1), ('운연동', 1), ('대별동', 1), ('주전동', 1), ('어물동', 1), ('와촌동', 1), ('죽장면', 1), ('기북면', 1), ('동빈1가', 1), ('서호동', 1), ('도동', 1), ('도학동', 1), ('덕곡동', 1), ('금호동', 1), ('동소문동1가', 1), ('안암동3가', 1), ('금남로2가', 1), ('천동', 1), ('사리현동', 1), ('안암동4가', 1), ('대림동', 1), ('본촌동', 1), ('보문동6가', 1)]
